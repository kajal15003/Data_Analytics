# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_excel("Privacy_survey.xlsx")

# %%
cnct= df[df.columns[0]], df[df.columns[5:21]]
df= pd.concat(cnct, axis=1)

# %%
df= pd.concat(cnct, axis=1)
df.columns=['ID','Expertise','Gender','Education','Privacy_Issue','Privacy_Leakage','Effect_PL','Risk_data','Risk_Phase','Hide_info','More_privacy','Pri_example','Privacy_premise','Regulation','Reg_help','Resposibility','Reg_effect']
df
# Out:
#       ID                                          Expertise Gender  \
# 0      1  I am very familiar with video surveillance sys...    Man
# 1      2  I am very familiar with video surveillance sys...    Man
# 2      3  I am very familiar with video surveillance sys...  Woman
# 3      4  I am very familiar with video surveillance sys...  Woman
# 4      5  I am very familiar with video surveillance sys...  Woman
# ..   ...                                                ...    ...
# 167  168  I am very familiar with video surveillance sys...    Man
# 168  169  I am very familiar with video surveillance sys...    Man
# 169  170  I am very familiar with video surveillance sys...  Woman
# 170  171    I have never heard of video surveillance system  Woman
# 171  172    I have never heard of video surveillance system  Woman
#
#                                   Education Privacy_Issue Privacy_Leakage  \
# 0                         Bachelor's degree     Very much       Sometimes
# 1                         Bachelor's degree      Not sure           Never
# 2                         Bachelor's degree    Not at all           Never
# 3                     High school graduate       Not sure           Never
# 4                     High school graduate      Very much           Never
# ..                                      ...           ...             ...
# 167                   High school graduate       Not sure           Never
# 168  Graduate degree (e.g., M.S. and Ph.D.)    Not at all           Never
# 169                   High school graduate      Very much           Never
# 170                   High school graduate       Not sure       Sometimes
# 171                   High school graduate     Not at all    Not aware of
#
#                         Effect_PL  \
# 0                             nil
# 1                             NaN
# 2                             NaN
# 3                               -
# 4                             NaN
# ..                            ...
# 167                         Never
# 168                           NaN
# 169                           NaN
# 170  didn’t really affect me much
# 171                           NaN
#
#                                              Risk_data  \
# 0    My identity can be inferred via face recogniti...
# 1    My location information is recorded and analys...
# 2    My identity can be inferred via face recogniti...
# 3    My identity can be inferred via face recogniti...
# 4    My personal belongings (e.g., car, handbag) ar...
# ..                                                 ...
# 167  My behaviour is recorded and analysed for adva...
# 168  My personal belongings (e.g., car, handbag) ar...
# 169  My identity can be inferred via face recogniti...
# 170  My footage is capture by the video surveillanc...
# 171  My identity can be inferred via face recogniti...
#
#                                             Risk_Phase  \
# 0    When data transmit from one server to other se...
# 1       When data is analysed on computational servers
# 2    When data is recorded on storage servers (loca...
# 3       When data is analysed on computational servers
# 4    When data transmit from one server to other se...
# ..                                                 ...
# 167  When data is viewed and analysed by security o...
# 168  When data is recorded on storage servers (loca...
# 169  When data transmit from one server to other se...
# 170                                         Don't Know
# 171     When data is analysed on computational servers
#
#                                  Hide_info              More_privacy  \
# 0                       Hide only the face      b (face region only)
# 1                       Hide only the face            d (full image)
# 2          Hide the background/environment            d (full image)
# 3                       Hide only the face  c (face and body region)
# 4                       Hide only the face  c (face and body region)
# ..                                     ...                       ...
# 167                     Hide only the face      b (face region only)
# 168                     Hide only the face            d (full image)
# 169  Hide the full body (from head to toe)  c (face and body region)
# 170  Hide the full body (from head to toe)  c (face and body region)
# 171                     Hide only the face      b (face region only)
#
#            Pri_example         Privacy_premise Regulation  Reg_help  \
# 0                    b  Hospitals/Universities   Heard of  May help
# 1     All of the above       Companies/Offices   Heard of  May help
# 2                    b  Hospitals/Universities   Familiar  May help
# 3    None of the above       Companies/Offices   Heard of  May help
# 4                    c          Public streets   Heard of  Not sure
# ..                 ...                     ...        ...       ...
# 167   All of the above  Hospitals/Universities   Familiar  Not sure
# 168                  c            Parking lots   Heard of  Not sure
# 169                  c  Hospitals/Universities   Heard of  Not sure
# 170                  c          Public streets   Heard of  Not sure
# 171                  b       Companies/Offices   Heard of  May help
#
#                                          Resposibility  \
# 0    Companies/organizations that use the video sur...
# 1                                           Government
# 2    Companies/organizations that use the video sur...
# 3    Companies/organizations that use the video sur...
# 4    Companies/organizations that use the video sur...
# ..                                                 ...
# 167  Companies/organizations that use the video sur...
# 168  Companies/organizations that use the video sur...
# 169                                         Government
# 170                                         Government
# 171  Companies/organizations that use the video sur...
#
#                                             Reg_effect
# 0                                             not much
# 1                                  Protects my privacy
# 2                        It raise the awareness to me.
# 3    it just makes me aware that there’s such thing...
# 4    They are supposed to ensure that our data is k...
# ..                                                 ...
# 167  Not really as they're stringent in approach an...
# 168  It has increased some administrative burden on...
# 169                                                NaN
# 170                         not much effect on my life
# 171  peace of mind knowing that there is a law in p...
#
# [172 rows x 17 columns]

# %%
df = pd.read_excel("1.xlsx")
df
# Out:
#    Unnamed: 0  ID  Expertise Gender                               Education  \
# 0          55  56          1    Man  Graduate degree (e.g., M.S. and Ph.D.)
#
#   Privacy_Issue Privacy_Leakage  \
# 0     Very much    Not aware of
#
#                                            Effect_PL  \
# 0  Some people may  well know my daily life and m...
#
#                                            Risk_data  \
# 0  My footage is capture by the video surveillanc...
#
#                                        Risk_Phase           Hide_info  \
# 0  When data is analysed on computational servers  Hide only the face
#
#      More_privacy       Pri_example  Privacy_premise Regulation      Reg_help  \
# 0  d (full image)  All of the above  Shopping centre   Heard of  Greatly help
#
#                                        Resposibility    Reg_effect
# 0  Companies/organizations that use the video sur...  Not aware of

# %%
grouped = df.groupby("Privacy_Issue") # change "Column Header Name" to the name of the column needed to categorise or group the rows in the dataframe, 
keys = grouped.groups.keys() #create a dictionary list of the each group unique varibles in the specifed column of the dataframe.   
print(keys) #a cheeky debug to check it's working
ax=df.groupby("Privacy_Issue")['Privacy_Issue'].count().plot(kind='pie',autopct='%0.2f%%',figsize=(5,5),legend=True,ylabel='',labeldistance=None,shadow=True)
ax.legend(bbox_to_anchor=(0.9, 1.1), loc='upper left')
# Out:
# dict_keys(['Very much'])

# %%
for key in keys: #looping through each key 
        splitdf = grouped.get_group(key) # creating a temporary dataframe with only the values of the current key. 
        splitdf.to_excel(str(key)+".xlsx", engine='xlsxwriter') #write the temporary dataframe called 'splitdf' to an excel file named after the key. At the end of the loop the temporary dataframe 'splitdf' is overwritten for use with the next key.

# %%
df = pd.read_excel("2.xlsx")
grouped = df.groupby("More_privacy") # change "Column Header Name" to the name of the column needed to categorise or group the rows in the dataframe, 
keys = grouped.groups.keys() #create a dictionary list of the each group unique varibles in the specifed column of the dataframe.   
print(keys) #a cheeky debug to check it's working
ax=df.groupby("More_privacy")['More_privacy'].count().plot(kind='pie',autopct='%0.2f%%',figsize=(5,5),legend=True,ylabel='Worked',labeldistance=None,shadow=True)
ax.legend(bbox_to_anchor=(0.8, 1.1), loc='upper left')
fig = ax.get_figure()
fig.savefig("/home/k/kajal/Survey_plots/myplot.pdf")
# Out:
# dict_keys(['b (face region only)', 'c (face and body region)', 'd (full image)'])

# %%
grouped = df.groupby("Risk_Phase") # change "Column Header Name" to the name of the column needed to categorise or group the rows in the dataframe, 
keys = grouped.groups.keys() #create a dictionary list of the each group unique varibles in the specifed column of the dataframe.   
#print(keys) #a cheeky debug to check it's working
ax=df.groupby("Risk_Phase")['Risk_Phase'].count()
ax.plot(kind='bar',legend=True)
ax.legend(bbox_to_anchor=(0.9, 1.1), loc='upper left')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-22-83b33d1ecf85> in <module>
#       4 ax=df.groupby("Risk_Phase")['Risk_Phase'].count()
#       5 ax.plot(kind='bar',legend=True)
# ----> 6 ax.legend(bbox_to_anchor=(0.9, 1.1), loc='upper left')
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5463             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5464                 return self[name]
# -> 5465             return object.__getattribute__(self, name)
#    5466
#    5467     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'Series' object has no attribute 'legend'
